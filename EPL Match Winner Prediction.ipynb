# %%
# I just used the data for 2020-2021 and 2021-2022 season (two season) for this machine learning
# Because the EPL is biggest league in the World, so there are so many players move to other team every season
# so I think that to use the recent two season's data can make best prediction

# import pandas
import pandas as pd

# %%
# The match data for 2020-2021 season and 2021-2022 season.

matches = pd.read_csv("/Users/hyunjesung/Desktop/epl/matches.csv", index_col = 0) # first column has just index

# %%
matches.shape # (1389, 27) 

#In epl, there is 38 matches for each team in one season (19 opponenets and 2 games with each opponents). 
#There is 20 teams and 2 seasons.
# total 38 * 20 * 2 = 1520 matches.
#But this data have only 1389 rows
# Out:
# (1389, 27)

# %%
# To check the missing data, 

matches["team"].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
# Each season, the bottom three teams are relegated to the second division (EFL Championship),
#and the top three teams in the second division are moved up to the first division (EPL).
# So there's total 23 teams in data
# But liverpool never relegated = liverpool's data is missing.
# and we also can find there's some matches missing for other teams becuase each team who did not 
#relegated must have 76(38 *2) matches.

# %%
# so check the rounds(matchweek) to which data is missing.

matches["round"].value_counts()

# Through this data, we can find that there's some data is missing from Matchweek 30,27,22,etc.
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %%
matches.dtypes # To check data type because ML only work with numeric data (float or int)
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"]= pd.to_datetime(matches["date"]) # to replace type of 'date' with datetime

# %%
matches["home/away"] = matches["venue"].astype("category").cat.codes 
# to set venue section as 0 and 1 (0 = away 1 = home)

# %%
matches["teamcode"] = matches['opponent'].astype("category").cat.codes
#to set team code (each team will get numeric code)

# %%
matches['matchtime'] = matches['time'].str.replace(":.+","",regex=True).astype("int")
# to replace : time section and set new colum 'match time' with integer type

# %%
matches["datecode"] = matches["date"].dt.dayofweek

# %%
# Train ML model
matches["target"] = (matches["result"]=="W").astype("int") # if result is 'W', return 1. else 0

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...   fk   pk  pkatt season              team  \
# 1        Tottenham  1.9  ...  1.0  0.0    0.0   2022   Manchester City
# 2     Norwich City  2.7  ...  1.0  0.0    0.0   2022   Manchester City
# 3          Arsenal  3.8  ...  0.0  0.0    0.0   2022   Manchester City
# 4   Leicester City  2.9  ...  0.0  0.0    0.0   2022   Manchester City
# 6      Southampton  1.1  ...  1.0  0.0    0.0   2022   Manchester City
# ..             ...  ...  ...  ...  ...    ...    ...               ...
# 38       Tottenham  0.5  ...  0.0  0.0    0.0   2021  Sheffield United
# 39  Crystal Palace  0.7  ...  1.0  0.0    0.0   2021  Sheffield United
# 40         Everton  1.6  ...  0.0  0.0    0.0   2021  Sheffield United
# 41   Newcastle Utd  0.8  ...  1.0  0.0    0.0   2021  Sheffield United
# 42         Burnley  0.6  ...  0.0  0.0    0.0   2021  Sheffield United
#
#    home/away teamcode  matchtime  datecode  target
# 1          0       18         16         6       0
# 2          1       15         15         5       1
# 3          1        0         12         5       1
# 4          0       10         15         5       1
# 6          1       17         15         5       0
# ..       ...      ...        ...       ...     ...
# 38         0       18         19         6       0
# 39         1        6         15         5       0
# 40         0        7         19         6       1
# 41         0       14         18         2       0
# 42         1        4         16         6       1
#
# [1389 rows x 30 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50,min_samples_split = 10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']
test = matches[matches["date"] > '2022-01-01']
predictors = ["home/away", "teamcode", "matchtime", "datecode"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score #to predict win/lose by match time

# %%
error = accuracy_score(test["target"], preds)

# %%
error # 61.2%
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          141  31
# 1           76  28

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds) # when we predict as win, only 47 percent accuracy
# so I should improve precision
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")
group
# Out:
#          date   time         round  day venue result   gf   ga  \
# 0  2020-09-21  20:15   Matchweek 2  Mon  Away      W  3.0  1.0
# 2  2020-09-27  16:30   Matchweek 3  Sun  Home      L  2.0  5.0
# 4  2020-10-03  17:30   Matchweek 4  Sat  Away      D  1.0  1.0
# 5  2020-10-17  17:30   Matchweek 5  Sat  Home      W  1.0  0.0
# 7  2020-10-24  12:30   Matchweek 6  Sat  Away      D  1.0  1.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 42 2022-03-14  20:00  Matchweek 29  Mon  Away      D  0.0  0.0
# 44 2022-04-02  15:00  Matchweek 31  Sat  Away      W  2.0  0.0
# 46 2022-04-10  16:30  Matchweek 32  Sun  Home      D  2.0  2.0
# 49 2022-04-20  20:00  Matchweek 30  Wed  Home      W  3.0  0.0
# 50 2022-04-23  15:00  Matchweek 34  Sat  Home      W  5.0  1.0
#
#           opponent   xg  ...   fk   pk  pkatt season             team  \
# 0           Wolves  1.9  ...  2.0  1.0    1.0   2021  Manchester City
# 2   Leicester City  0.9  ...  1.0  0.0    0.0   2021  Manchester City
# 4     Leeds United  1.5  ...  1.0  0.0    0.0   2021  Manchester City
# 5          Arsenal  1.5  ...  0.0  0.0    0.0   2021  Manchester City
# 7         West Ham  1.1  ...  1.0  0.0    0.0   2021  Manchester City
# ..             ...  ...  ...  ...  ...    ...    ...              ...
# 42  Crystal Palace  2.3  ...  0.0  0.0    0.0   2022  Manchester City
# 44         Burnley  1.8  ...  0.0  0.0    0.0   2022  Manchester City
# 46       Liverpool  2.0  ...  1.0  0.0    0.0   2022  Manchester City
# 49        Brighton  1.2  ...  0.0  0.0    0.0   2022  Manchester City
# 50         Watford  3.0  ...  0.0  1.0    1.0   2022  Manchester City
#
#    home/away teamcode  matchtime  datecode  target
# 0          0       22         20         0       1
# 2          1       10         16         6       0
# 4          0        9         17         5       0
# 5          1        0         17         5       1
# 7          0       21         12         5       0
# ..       ...      ...        ...       ...     ...
# 42         0        6         20         0       0
# 44         0        4         15         5       1
# 46         1       11         16         6       0
# 49         1        3         20         2       1
# 50         1       19         15         5       1
#
# [71 rows x 30 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"] # gf = goals for ,ga = goals against, sot = shots on target
# dist = distance that shot taken, fk = free kick, pk= penalty kick, pkatt= pk attempts  
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 5  2020-10-17  17:30   Matchweek 5  Sat  Home      W  1.0  0.0
# 7  2020-10-24  12:30   Matchweek 6  Sat  Away      D  1.0  1.0
# 9  2020-10-31  12:30   Matchweek 7  Sat  Away      W  1.0  0.0
# 11 2020-11-08  16:30   Matchweek 8  Sun  Home      D  1.0  1.0
# 12 2020-11-21  17:30   Matchweek 9  Sat  Away      L  0.0  2.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 42 2022-03-14  20:00  Matchweek 29  Mon  Away      D  0.0  0.0
# 44 2022-04-02  15:00  Matchweek 31  Sat  Away      W  2.0  0.0
# 46 2022-04-10  16:30  Matchweek 32  Sun  Home      D  2.0  2.0
# 49 2022-04-20  20:00  Matchweek 30  Wed  Home      W  3.0  0.0
# 50 2022-04-23  15:00  Matchweek 34  Sat  Home      W  5.0  1.0
#
#           opponent   xg  ...  datecode  target  gf_rolling ga_rolling  \
# 5          Arsenal  1.5  ...         5       1    2.000000   2.333333
# 7         West Ham  1.1  ...         5       0    1.333333   2.000000
# 9    Sheffield Utd  1.5  ...         5       1    1.000000   0.666667
# 11       Liverpool  1.6  ...         6       0    1.000000   0.333333
# 12       Tottenham  1.3  ...         5       0    1.000000   0.666667
# ..             ...  ...  ...       ...     ...         ...        ...
# 42  Crystal Palace  2.3  ...         0       0    2.333333   1.333333
# 44         Burnley  1.8  ...         5       1    1.666667   0.333333
# 46       Liverpool  2.0  ...         6       0    2.000000   0.333333
# 49        Brighton  1.2  ...         2       1    1.333333   0.666667
# 50         Watford  3.0  ...         5       1    2.333333   0.666667
#
#    sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 5   17.333333    4.666667    18.900000    1.333333    0.333333       0.333333
# 7   17.333333    3.666667    17.733333    0.666667    0.000000       0.000000
# 9   16.666667    4.333333    18.233333    0.666667    0.000000       0.000000
# 11  14.333333    6.666667    18.466667    1.000000    0.000000       0.000000
# 12  12.000000    5.666667    19.366667    1.000000    0.000000       0.333333
# ..        ...         ...          ...         ...         ...            ...
# 42  19.000000    7.000000    15.366667    0.333333    0.333333       0.333333
# 44  18.333333    7.333333    16.000000    0.333333    0.000000       0.000000
# 46  20.000000    6.666667    16.133333    0.333333    0.000000       0.000000
# 49  15.666667    4.666667    16.700000    0.333333    0.000000       0.000000
# 50  15.333333    5.000000    17.200000    0.333333    0.000000       0.000000
#
# [68 rows x 38 columns]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_avg(group,cols,new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 5  2020-10-17  17:30   Matchweek 5  Sat  Home      W  1.0  0.0
# 7  2020-10-24  12:30   Matchweek 6  Sat  Away      D  1.0  1.0
# 9  2020-10-31  12:30   Matchweek 7  Sat  Away      W  1.0  0.0
# 11 2020-11-08  16:30   Matchweek 8  Sun  Home      D  1.0  1.0
# 12 2020-11-21  17:30   Matchweek 9  Sat  Away      L  0.0  2.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 42 2022-03-14  20:00  Matchweek 29  Mon  Away      D  0.0  0.0
# 44 2022-04-02  15:00  Matchweek 31  Sat  Away      W  2.0  0.0
# 46 2022-04-10  16:30  Matchweek 32  Sun  Home      D  2.0  2.0
# 49 2022-04-20  20:00  Matchweek 30  Wed  Home      W  3.0  0.0
# 50 2022-04-23  15:00  Matchweek 34  Sat  Home      W  5.0  1.0
#
#           opponent   xg  ...  datecode  target  gf_rolling ga_rolling  \
# 5          Arsenal  1.5  ...         5       1    2.000000   2.333333
# 7         West Ham  1.1  ...         5       0    1.333333   2.000000
# 9    Sheffield Utd  1.5  ...         5       1    1.000000   0.666667
# 11       Liverpool  1.6  ...         6       0    1.000000   0.333333
# 12       Tottenham  1.3  ...         5       0    1.000000   0.666667
# ..             ...  ...  ...       ...     ...         ...        ...
# 42  Crystal Palace  2.3  ...         0       0    2.333333   1.333333
# 44         Burnley  1.8  ...         5       1    1.666667   0.333333
# 46       Liverpool  2.0  ...         6       0    2.000000   0.333333
# 49        Brighton  1.2  ...         2       1    1.333333   0.666667
# 50         Watford  3.0  ...         5       1    2.333333   0.666667
#
#    sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 5   17.333333    4.666667    18.900000    1.333333    0.333333       0.333333
# 7   17.333333    3.666667    17.733333    0.666667    0.000000       0.000000
# 9   16.666667    4.333333    18.233333    0.666667    0.000000       0.000000
# 11  14.333333    6.666667    18.466667    1.000000    0.000000       0.000000
# 12  12.000000    5.666667    19.366667    1.000000    0.000000       0.333333
# ..        ...         ...          ...         ...         ...            ...
# 42  19.000000    7.000000    15.366667    0.333333    0.333333       0.333333
# 44  18.333333    7.333333    16.000000    0.333333    0.000000       0.000000
# 46  20.000000    6.666667    16.133333    0.333333    0.000000       0.000000
# 49  15.666667    4.666667    16.700000    0.333333    0.000000       0.000000
# 50  15.333333    5.000000    17.200000    0.333333    0.000000       0.000000
#
# [68 rows x 38 columns]

# %%
#set group by team
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 6  2020-10-04  14:00   Matchweek 4  Sun  Home      W
#                         7  2020-10-17  17:30   Matchweek 5  Sat  Away      L
#                         9  2020-10-25  19:15   Matchweek 6  Sun  Home      L
#                         11 2020-11-01  16:30   Matchweek 7  Sun  Away      W
#                         13 2020-11-08  19:15   Matchweek 8  Sun  Home      L
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Matchweek 29  Sun  Away      W
#                         33 2022-03-18  20:00  Matchweek 30  Fri  Home      L
#                         34 2022-04-02  15:00  Matchweek 31  Sat  Home      W
#                         35 2022-04-08  20:00  Matchweek 32  Fri  Away      L
#                         36 2022-04-24  14:00  Matchweek 34  Sun  Away      L
#
#                              gf   ga         opponent   xg  ...  datecode  \
# team                                                        ...
# Arsenal                 6   2.0  1.0    Sheffield Utd  0.4  ...         6
#                         7   0.0  1.0  Manchester City  0.9  ...         5
#                         9   0.0  1.0   Leicester City  0.9  ...         6
#                         11  1.0  0.0   Manchester Utd  1.1  ...         6
#                         13  0.0  3.0      Aston Villa  1.5  ...         6
# ...                         ...  ...              ...  ...  ...       ...
# Wolverhampton Wanderers 32  1.0  0.0          Everton  0.8  ...         6
#                         33  2.0  3.0     Leeds United  0.8  ...         4
#                         34  2.0  1.0      Aston Villa  1.2  ...         5
#                         35  0.0  1.0    Newcastle Utd  0.3  ...         4
#                         36  0.0  1.0          Burnley  0.7  ...         6
#
#                             target  gf_rolling ga_rolling sh_rolling  \
# team
# Arsenal                 6        1    2.000000   1.333333   7.666667
#                         7        0    1.666667   1.666667   5.333333
#                         9        0    1.000000   1.666667   7.000000
#                         11       1    0.666667   1.000000   9.666667
#                         13       0    0.333333   0.666667   9.666667
# ...                            ...         ...        ...        ...
# Wolverhampton Wanderers 32       1    1.333333   1.000000  12.333333
#                         33       0    1.666667   0.666667  12.333333
#                         34       1    2.333333   1.000000  13.000000
#                         35       0    1.666667   1.333333  13.000000
#                         36       0    1.333333   1.666667  10.000000
#
#                            sot_rolling dist_rolling  fk_rolling  pk_rolling  \
# team
# Arsenal                 6     3.666667    14.733333    0.666667    0.000000
#                         7     3.666667    15.766667    0.000000    0.000000
#                         9     3.666667    16.733333    0.666667    0.000000
#                         11    4.000000    16.033333    1.000000    0.000000
#                         13    2.666667    18.033333    1.000000    0.333333
# ...                                ...          ...         ...         ...
# Wolverhampton Wanderers 32    3.666667    19.300000    0.000000    0.000000
#                         33    4.333333    19.600000    0.000000    0.000000
#                         34    5.333333    19.833333    0.000000    0.000000
#                         35    5.000000    18.533333    0.000000    0.000000
#                         36    4.666667    17.633333    0.000000    0.000000
#
#                             pkatt_rolling
# team
# Arsenal                 6        0.000000
#                         7        0.000000
#                         9        0.000000
#                         11       0.000000
#                         13       0.333333
# ...                                   ...
# Wolverhampton Wanderers 32       0.000000
#                         33       0.000000
#                         34       0.000000
#                         35       0.000000
#                         36       0.000000
#
# [1317 rows x 38 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga  \
# 6  2020-10-04  14:00   Matchweek 4  Sun  Home      W  2.0  1.0
# 7  2020-10-17  17:30   Matchweek 5  Sat  Away      L  0.0  1.0
# 9  2020-10-25  19:15   Matchweek 6  Sun  Home      L  0.0  1.0
# 11 2020-11-01  16:30   Matchweek 7  Sun  Away      W  1.0  0.0
# 13 2020-11-08  19:15   Matchweek 8  Sun  Home      L  0.0  3.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 32 2022-03-13  14:00  Matchweek 29  Sun  Away      W  1.0  0.0
# 33 2022-03-18  20:00  Matchweek 30  Fri  Home      L  2.0  3.0
# 34 2022-04-02  15:00  Matchweek 31  Sat  Home      W  2.0  1.0
# 35 2022-04-08  20:00  Matchweek 32  Fri  Away      L  0.0  1.0
# 36 2022-04-24  14:00  Matchweek 34  Sun  Away      L  0.0  1.0
#
#            opponent   xg  ...  datecode  target  gf_rolling ga_rolling  \
# 6     Sheffield Utd  0.4  ...         6       1    2.000000   1.333333
# 7   Manchester City  0.9  ...         5       0    1.666667   1.666667
# 9    Leicester City  0.9  ...         6       0    1.000000   1.666667
# 11   Manchester Utd  1.1  ...         6       1    0.666667   1.000000
# 13      Aston Villa  1.5  ...         6       0    0.333333   0.666667
# ..              ...  ...  ...       ...     ...         ...        ...
# 32          Everton  0.8  ...         6       1    1.333333   1.000000
# 33     Leeds United  0.8  ...         4       0    1.666667   0.666667
# 34      Aston Villa  1.2  ...         5       1    2.333333   1.000000
# 35    Newcastle Utd  0.3  ...         4       0    1.666667   1.333333
# 36          Burnley  0.7  ...         6       0    1.333333   1.666667
#
#    sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 6    7.666667    3.666667    14.733333    0.666667    0.000000       0.000000
# 7    5.333333    3.666667    15.766667    0.000000    0.000000       0.000000
# 9    7.000000    3.666667    16.733333    0.666667    0.000000       0.000000
# 11   9.666667    4.000000    16.033333    1.000000    0.000000       0.000000
# 13   9.666667    2.666667    18.033333    1.000000    0.333333       0.333333
# ..        ...         ...          ...         ...         ...            ...
# 32  12.333333    3.666667    19.300000    0.000000    0.000000       0.000000
# 33  12.333333    4.333333    19.600000    0.000000    0.000000       0.000000
# 34  13.000000    5.333333    19.833333    0.000000    0.000000       0.000000
# 35  13.000000    5.000000    18.533333    0.000000    0.000000       0.000000
# 36  10.000000    4.666667    17.633333    0.000000    0.000000       0.000000
#
# [1317 rows x 38 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0]) # to set unique index for each match

# %%
# re-train ML model
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error # my ML model's accuracy
# Out:
# 0.625

# %%
combined # see the prediction results
# Out:
#       actual  predicted
# 55         0          0
# 56         1          0
# 57         1          0
# 58         1          1
# 59         1          1
# ...      ...        ...
# 1312       1          0
# 1313       0          0
# 1314       1          0
# 1315       0          0
# 1316       0          0
#
# [276 rows x 2 columns]

# %%
#to add match date, team, opponent, and result in combined
combined = combined.merge(matches_rolling[["date","team","opponent","result"]],left_index=True, right_index= True)

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          0 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# 58        W
# 59        W
# ...     ...
# 1312      W
# 1313      L
# 1314      W
# 1315      L
# 1316      L
#
# [276 rows x 6 columns]

# %%
# as in example above, the opponent name and team name is not same ( ex) Wolverhampton Wanderers and Wolves
class MissingDict(dict):
    __missing__= lambda self,key:key
    
map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd", 
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
mapping["Brighton and Hove Albion"]
# Out:
# 'Brighton'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          0 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result new_team
# 55        D  Arsenal
# 56        W  Arsenal
# 57        W  Arsenal
# 58        W  Arsenal
# 59        W  Arsenal
# ...     ...      ...
# 1312      W   Wolves
# 1313      L   Wolves
# 1314      W   Wolves
# 1315      L   Wolves
# 1316      L   Wolves
#
# [276 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#     result_x new_team_x  actual_y  predicted_y                   team_y  \
# 0          D    Arsenal         0            0                  Burnley
# 1          W    Arsenal         0            0  Wolverhampton Wanderers
# 2          W    Arsenal         0            0                Brentford
# 3          W    Arsenal         0            0  Wolverhampton Wanderers
# 4          W    Arsenal         0            0                  Watford
# ..       ...        ...       ...          ...                      ...
# 257        W     Wolves         0            0                  Everton
# 258        L     Wolves         1            0             Leeds United
# 259        W     Wolves         0            0              Aston Villa
# 260        L     Wolves         1            0         Newcastle United
# 261        L     Wolves         1            0                  Burnley
#
#     opponent_y result_y     new_team_y
# 0      Arsenal        D        Burnley
# 1      Arsenal        L         Wolves
# 2      Arsenal        L      Brentford
# 3      Arsenal        L         Wolves
# 4      Arsenal        L        Watford
# ..         ...      ...            ...
# 257     Wolves        L        Everton
# 258     Wolves        W   Leeds United
# 259     Wolves        L    Aston Villa
# 260     Wolves        W  Newcastle Utd
# 261     Wolves        W        Burnley
#
# [262 rows x 13 columns]

# %%
merged[(merged["predicted_x"]==1) & (merged["predicted_y"]==0)]["actual_x"].value_counts()
# Out:
# 1    27
# 0    13
# Name: actual_x, dtype: int64

# %%
# Out:
# 0.675
